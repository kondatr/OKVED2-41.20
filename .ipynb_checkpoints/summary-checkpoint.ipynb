# %%
import matplotlib.pyplot as plt

from graphs.revenue import revenue_map, revenue_top10_graph
from graphs.net_profit import growth_years_graph, net_profit_graph
from graphs.EBITDA import EBITDA_graph

# %%
revenue_map()

# %%
growth_years_graph()
# Out:
# Средний процент изменения чистой прибыли спустя 1 год(а): 366.66%
# Медианный процент изменения чистой прибыли спустя 1 год(а): 8.0%
# Средний процент изменения чистой прибыли спустя 2 год(а): 76.89%
# Медианный процент изменения чистой прибыли спустя 2 год(а): 12.0%
# Средний процент изменения чистой прибыли спустя 3 год(а): 3283.91%
# Медианный процент изменения чистой прибыли спустя 3 год(а): 15.0%
# Средний процент изменения чистой прибыли спустя 4 год(а): 5726.09%
# Медианный процент изменения чистой прибыли спустя 4 год(а): 17.0%
